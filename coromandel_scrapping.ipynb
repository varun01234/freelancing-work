# %%
    ++++++++++++++++++ from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd
import requests as rq
import numpy as np
import time as tm

# %%
data = []
for x in range(0, 100):

    
    url = str(productlinks[x])

#     url = "https://www.coromandel.biz/product-service/gromor-power-13-40-13/"
    driver = webdriver.Chrome()
    
    driver.get(url)

#     tm.sleep(5)
    content = driver.page_source.encode('utf-8').strip()
    soup = BeautifulSoup(content,"html.parser")
    
    try:
        name = soup.find("h4",{"class":"yellow-title text-left pb-3"}).text
#         print(name)
    except:
        names = None
    
    try:
        pack = soup.find("strong",{"class":"pack-size"}).text
#         print(pack)
    except:
        pack=None
    
    try:
        briefs = soup.find("div",{"class":"product-details pt-4"})
        bps = briefs.find_all("p")
        bpsl=[]
        for i in bps:
            bpsl.append(i.text)
        det = " ".join(bpsl)
            
    except:
        det=None
    
    try:
        do=""
        panel = soup.find_all("div",{"class":"panel panel-default"})
        for i in panel:
            head = i.find("h4").text.strip()
#             print(head)
            if head == "Dosage and Application" or head == "Dosage & Time of Application" or head == "Dosage & Application" or head == "Dosage":
                paras = i.find_all("li")
                if len(paras)==0:
                    paras = i.find_all("p")
                dosel=[]
                for i in paras:
                    dosel.append(i.text)
                do = " ".join(dosel)
    except:
        do=None

    try:
        fe=""
        panel = soup.find("div",{"class":"panel panel-default active"})
        head = panel.find("h4").text.strip()
        li = panel.find_all("li")
#         print(head)
        featurel=[]
        for i in li:
            featurel.append(i.text)
        fe = "\n".join(featurel)
    except:
        fe=None
        
    try:
        img = soup.find("img", {"class":"w-100"}).get('src')
#         print(img)
    except:
        img = None
        
    product = {"Product Name": name, "Brand Name": "Coromandel", "Detail": det, "Dose": do, "Pack Size": pack, "Features": fe,"Image Link": img, "Product Link": url}
    data.append(product)
    print(x)
    
    driver.quit()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
new_data = pd.DataFrame.from_dict(data)
pd.set_option('display.max_rows', None)
new_data.head(50)
# Out:
#   Product Name  Brand Name                                             Detail  \
# 0      ARITHRI  Coromandel  This is an Arbuscular Mycorrhizal Fungi contai...
# 1  FANTAC PLUS  Coromandel  A L-cysteine based plant growth regulator, it ...
# 2      PLATINA  Coromandel  It is a plant growth regulator, that is a comb...
# 3      PLATINA  Coromandel                                               None
# 4      PLATINA  Coromandel                                               None
# 5      PLATINA  Coromandel                                               None
# 6      PLATINA  Coromandel                                               None
# 7      PLATINA  Coromandel                                               None
# 8      PLATINA  Coromandel                                               None
#
#   Dose                                          Pack Size  \
# 0                                    Pack Size 2 Kg, 4 Kg
# 1       Pack Size 25 ml, 50 ml, 100 ml, 250 ml, 500 ml...
# ...

# %%
new_data.to_csv("file-plant-growth.csv")

# %%
df = pd.read_csv('coro.csv')

# %%
df.head(200)
# Out:
#      Unnamed: 0                     Product Name  Brand Name  \
# 0           0.0                  ACUMIST CALCIUM  Coromandel
# 1           1.0     FITSOL Grapes Grade 1, 2 & 3  Coromandel
# 2           2.0                     AcuMist Zinc  Coromandel
# 3           3.0                        SULPHAMAX  Coromandel
# 4           4.0                           BOSMAX  Coromandel
# 5           5.0                            INSTA  Coromandel
# 6           6.0                           SPONTA  Coromandel
# 7           7.0   FITSOL SOLANACEAE GRADES 1 & 2  Coromandel
# 8           8.0       FITSOL BANANA GRADES 1 & 2  Coromandel
# 9           9.0  FITSOL POMEGRANATE GRADES 1 & 2  Coromandel
# 10         10.0    FITSOL SUGARCANE GRADES 1 & 2  Coromandel
# 11         11.0                  ACUSPRAY CEREAL  Coromandel
# 12         12.0                  ACUSPRAY COTTON  Coromandel
# 13         13.0                  ACUSPRAY PULSES  Coromandel
# ...
